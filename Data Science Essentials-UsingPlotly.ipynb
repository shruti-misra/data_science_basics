# %%
#Import relevant libraries
import matplotlib.pyplot as plt
import numpy as np, pandas as pd
import seaborn as sns
import requests

import plotly.express as px
import plotly.tools as tls
import plotly.graph_objs as go
import cufflinks as cf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Load reliance dataset
reliance = pd.read_csv("/content/drive/MyDrive/Grad School-Files/Job Search/Data Science Basics/RELIANCE.csv", index_col='Date', parse_dates=True)
reliance = reliance.dropna(axis=1) #drop null columns

#Load awards dataset
awards = pd.read_csv("/content/drive/MyDrive/Grad School-Files/Job Search/Data Science Basics/Awards1920.csv")
awards = awards.dropna(axis=1) #drop null columns
awards['AwardedAmountToDate'] = pd.to_numeric(awards['AwardedAmountToDate'].str[1:].replace(',','', regex=True)) #Remove '$' and ',' from the amount and convert to number

# %% [markdown]
# ### Generate a basic line chart

# %%
fig = px.line(reliance, y=['Open', 'Close'],
              labels={
                     "value": "Stock Price (INR)",
                     "Date": "Year",
                     "variable": "Type of Price"
                 },
              title="Opening and Closing Stock Price of Reliance Industries from 2000-2021")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Generate a basic bar chart

# %%
#Group and sum award amounts by state
award_state = awards.groupby(['OrganizationState'])['AwardedAmountToDate'].sum().reset_index()
award_state = award_directorate.sort_values('AwardedAmountToDate', ascending=False)

# %%
fig = px.bar(award_state, x='OrganizationState', y= 'AwardedAmountToDate',
                           labels={
                     "AwardedAmountToDate": "Award Amount ($)",
                     "OrganizationState": "State",
                 },
              title="Total Amount of Awards Granted to Organizations in Each State")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Generate Pie Chart

# %%
#Group and sum award amounts by NSF Directorate
award_directorate = awards.groupby(['NSFDirectorate'])['AwardedAmountToDate'].sum().reset_index()
award_directorate = award_directorate.sort_values('AwardedAmountToDate', ascending=False)

fig = px.pie(award_directorate, names='NSFDirectorate', values= 'AwardedAmountToDate',
              title="Total Amount of Grants Distributed by Each NSF Directorate")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Statistical Charts

# %% [markdown]
# ### 1. Histogram

# %%
fig = px.histogram(awards, x="AwardedAmountToDate",nbins=10, title="Histogram of Award Amounts")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Boxplots

# %%
award_directorate = awards.groupby(['NSFDirectorate'])['AwardedAmountToDate'].sum().reset_index()
award_directorate = award_directorate.sort_values('AwardedAmountToDate', ascending=False)

fig = px.box(awards, x='NSFDirectorate', y="AwardedAmountToDate",
             labels={
                     "AwardedAmountToDate": "Award Amount ($)",
                     "NSFDirectorate": "Directorate",
                 },
             title="Boxplots of Award Amounts by Directorate")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
